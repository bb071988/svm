# %%
# %matplotlib inline

# %%
import numpy as np

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %%
import matplotlib.pyplot as plt
plt.scatter(iris.data[:, 1], iris.data[:, 2], c=iris.target)
plt.xlabel(iris.feature_names[1])
plt.ylabel(iris.feature_names[2])

# %%
# iris.data[:100]
# iris.data.

# %%
#The first 100 observations correspond to setosa and versicolor
plt.scatter(iris.data[0:100, 1], iris.data[0:100, 2], c=iris.target[0:100])
plt.xlabel(iris.feature_names[1])
plt.ylabel(iris.feature_names[2])

# %%
from sklearn import svm
svc = svm.SVC(kernel='linear')
from sklearn import datasets
X = iris.data[0:100, 1:3]
y = iris.target[0:100]
svc.fit(X, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#Adapted from https://github.com/jakevdp/sklearn_scipy2013
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

def plot_estimator(estimator, X, y):
    estimator.fit(X, y)
    x_min, x_max = X[:, 0].min() - .1, X[:, 0].max() + .1
    y_min, y_max = X[:, 1].min() - .1, X[:, 1].max() + .1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                         np.linspace(y_min, y_max, 100))
    Z = estimator.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
    plt.axis('tight')
    plt.axis('off')
    plt.tight_layout()

plot_estimator(svc, X, y)

# %%
# just setosa and versicolor

# %%
# get combinations of features
# itertools.combinations(iterable, r)
from itertools import combinations
combo = list((combinations(a, 2)))
print(combo)

#The first 100 observations correspond to setosa and versicolor
for pair in range(len(combo)):
#     print(combo[pair])
#     print(combo[pair][0])
#     print(combo[pair][1])

    plt.figure()
    plt.scatter(iris.data[0:100, combo[pair][0]], iris.data[0:100, combo[pair][1]], c=iris.target[0:100])
    plt.xlabel(iris.feature_names[combo[pair][0]])
    plt.ylabel(iris.feature_names[combo[pair][1]])
    plt.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b78e6a938ec3> in <module>()
#       2 # itertools.combinations(iterable, r)
#       3 from itertools import combinations
# ----> 4 combo = list((combinations(a, 2)))
#       5 print(combo)
#       6
#
# NameError: name 'a' is not defined

# %%
# all flowers

# %%
# get combinations of features
# itertools.combinations(iterable, r)
from itertools import combinations
combo = list((combinations(a, 2)))
print(combo)

#The first 100 observations correspond to setosa and versicolor
for pair in range(len(combo)):
#     print(combo[pair])
#     print(combo[pair][0])
#     print(combo[pair][1])

    plt.figure()
    plt.scatter(iris.data[:, combo[pair][0]], iris.data[:, combo[pair][1]], c=iris.target[:])
    plt.xlabel(iris.feature_names[combo[pair][0]])
    plt.ylabel(iris.feature_names[combo[pair][1]])
    plt.plot()
    X = iris.data[:,combo[pair]]
    y = iris.target[:]
    plot_estimator(svc, X, y)

# %%
from sklearn import svm
svc = svm.SVC(kernel='linear')
from sklearn import datasets
X = iris.data[:, :]
y = iris.target[:]
svc.fit(X, y)

# %%
#Adapted from https://github.com/jakevdp/sklearn_scipy2013
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

def plot_estimator(estimator, X, y):
    estimator.fit(X, y)
    x_min, x_max = X[:, 0].min() - .1, X[:, 0].max() + .1
    y_min, y_max = X[:, 1].min() - .1, X[:, 1].max() + .1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                         np.linspace(y_min, y_max, 100))
    Z = estimator.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
    plt.axis('tight')
    plt.axis('off')
    plt.tight_layout()

plot_estimator(svc, X, y)

# %%
iris.feature_names

# %%
iris.data[0:100, 0] # first column rows 0 -100 - sepal length

# %%
iris.data[0:100,3]

# %%
# >>> from sympy.utilities.iterables import multiset_permutations
# >>> import numpy as np
# >>> a = np.array([0, 1, 0, 2])
# >>> for p in multiset_permutations(a):
# ...     p

# %%
from sympy.utilities.iterables import multiset_permutations

# %%
# these are permutations - we want combinations
a = np.array([0,1,2,3])
x = 0
for p in multiset_permutations(a):
    print(p)
    x +=1
print(x)

# %%
# itertools.combinations(iterable, r)
from itertools import combinations
list((combinations(a, 2)))
